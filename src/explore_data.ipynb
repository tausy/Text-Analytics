# %% [markdown]
# # Explore data

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
blog = pd.read_csv("data/blogs_clean.csv",sep="#")
print(len(blog))
blog
# Out:
# 681288
#         author  age  gender            date  \
# 0            0   16    male  19/August/2004
# 1            0   16    male  17/August/2004
# 2            0   16    male  16/August/2004
# 3            0   16    male  14/August/2004
# 4            0   16    male  09/August/2004
# 5            0   16    male  09/August/2004
# 6            0   16    male  07/August/2004
# 7            0   16    male  07/August/2004
# 8            1   25  female     29/May/2004
# 9            1   25  female    30/June/2004
# 10           1   25  female    29/June/2004
# 11           1   25  female    28/June/2004
# 12           1   25  female    28/June/2004
# 13           1   25  female    27/June/2004
# 14           1   25  female    26/June/2004
# 15           1   25  female    26/June/2004
# 16           1   25  female    25/June/2004
# 17           1   25  female    21/June/2004
# 18           1   25  female    20/June/2004
# 19           1   25  female    20/June/2004
# ...

# %%
blog['post'][0]
# Out:
# 'destini you might not say anyth but i can hear you have chosen me your life partner so have i dear so have i dear my first dream my first extrem my first love i wa wait for my destini what should i do with myself tell me o my heart what should i do with myself tell me should i fli with thi beauti natur or should i play with these wind should i tri to reach the sky or should i pray to the mother earth what should i do with myself friend tell me she talk in such a way gave me dream with thousand colour like i stand in the middl of island and she show me all the love she ha my first dream my first extrem my first love i wa wait for my destini nil'

# %% [markdown]
# ### Age

# %%
age = np.array(blog['age'])
len(age)
# Out:
# 681288

# %%
print(min(age),max(age))
# Out:
# 13 48

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(10,8))

ax.hist(age)
plt.title("Histogram of Blogger's Age",)
plt.ylabel('Frequency')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# ### gender

# %%
gender = np.array(blog['gender'])
print(len(gender))
blog['gender'].value_counts()
# Out:
# 681288
# male      345197
# female    336091
# Name: gender, dtype: int64

# %% [markdown]
# ### Post

# %%
post = np.array(blog['post'])
post[0]
# Out:
# 'destini you might not say anyth but i can hear you have chosen me your life partner so have i dear so have i dear my first dream my first extrem my first love i wa wait for my destini what should i do with myself tell me o my heart what should i do with myself tell me should i fli with thi beauti natur or should i play with these wind should i tri to reach the sky or should i pray to the mother earth what should i do with myself friend tell me she talk in such a way gave me dream with thousand colour like i stand in the middl of island and she show me all the love she ha my first dream my first extrem my first love i wa wait for my destini nil'

# %%
postLength = [len(str(p)) for p in post]
print(postLength[0])
print(min(postLength),max(postLength))
# Out:
# 651
# 1 663427

# %%
pd.Series(postLength).value_counts()
# Out:
# 3        4230
# 7        2531
# 28       1561
# 26       1561
# 34       1544
# 30       1528
# 36       1527
# 31       1527
# 20       1517
# 25       1508
# 32       1500
# 38       1497
# 33       1489
# 27       1481
# 37       1477
# 42       1457
# 41       1456
# 35       1451
# 29       1446
# 39       1419
# 46       1405
# 51       1401
# 44       1393
# 47       1381
# 43       1372
# 52       1357
# 48       1338
# 40       1334
# 45       1332
# 49       1326
#          ...
# 15481       1
# 19575       1
# 11119       1
# 9536        1
# 9476        1
# 12652       1
# 8836        1
# 7299        1
# 10375       1
# 12420       1
# 11628       1
# 8154        1
# 6273        1
# 8452        1
# 13959       1
# 5763        1
# 9349        1
# 6470        1
# 8837        1
# 12140       1
# 20619       1
# 16521       1
# 8964        1
# 11013       1
# 12764       1
# 11909       1
# 9860        1
# 9139        1
# 5378        1
# 7834        1
# ...

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(10,8))

l = [p for p in postLength if p<10000]


ax.hist(l)
plt.title("Histogram of Post Length",)
plt.ylabel('Frequency')
plt.xlabel('Length')
# Out:
# Text(0.5, 0, 'Length')
